# %%
from tkinter import*
def click(num):
    global empty
    empty=empty+ str(num)
    inputval.set(empty)
def clear():
    global empty
    empty=""
    inputval.set(empty)
def equalto():
    global empty
    sumup=str(eval(empty))
    inputval.set(sumup)
    empty=""
calculator=Tk()
calculator.title("CALCULATOR")
empty=""
inputval= StringVar()
#screen of calculator
screen=Entry(calculator,font=('arial',20,"bold"), bd=30, insertwidth=4,text=inputval,bg="powder blue", justify="right").grid(columnspan=4)
#buttons
#________________________________________________________________________________________________________
button7=Button(calculator,padx=20,pady=10,bd=8, fg="black",font=("arial",20,"bold"),text="7",command=lambda:click(7),bg="powder blue").grid(row=1,column=0)
button8=Button(calculator,padx=20,pady=10,bd=8, fg="black",font=("arial",20,"bold"),text="8",command=lambda:click(8),bg="powder blue").grid(row=1,column=1)
button9=Button(calculator,padx=20,pady=10,bd=8, fg="black",font=("arial",20,"bold"),text="9",command=lambda:click(9),bg="powder blue").grid(row=1,column=2)
add=Button(calculator,padx=20,pady=10,bd=8, fg="black",font=("arial",20,"bold"),text="+",command=lambda:click("+"),bg="powder blue").grid(row=1,column=3)
#________________________________________________________________________________________________________
button4=Button(calculator,padx=20,pady=10,bd=8, fg="black",font=("arial",20,"bold"),text="4",command=lambda:click(4),bg="powder blue").grid(row=2,column=0)
button5=Button(calculator,padx=20,pady=10,bd=8, fg="black",font=("arial",20,"bold"),text="5",command=lambda:click(5),bg="powder blue").grid(row=2,column=1)
button6=Button(calculator,padx=20,pady=10,bd=8, fg="black",font=("arial",20,"bold"),text="6",command=lambda:click(6),bg="powder blue").grid(row=2,column=2)
sub=Button(calculator,padx=20,pady=10,bd=8, fg="black",font=("arial",20,"bold"),text="-",command=lambda:click("-"),bg="powder blue").grid(row=2,column=3)
#________________________________________________________________________________________________________
button1=Button(calculator,padx=20,pady=10,bd=8, fg="black",font=("arial",20,"bold"),text="1",command=lambda:click(1),bg="powder blue").grid(row=3,column=0)
button2=Button(calculator,padx=20,pady=10,bd=8, fg="black",font=("arial",20,"bold"),text="2",command=lambda:click(2),bg="powder blue").grid(row=3,column=1)
button3=Button(calculator,padx=20,pady=10,bd=8, fg="black",font=("arial",20,"bold"),text="3",command=lambda:click(3),bg="powder blue").grid(row=3,column=2)
mult=Button(calculator,padx=20,pady=10,bd=8, fg="black",font=("arial",20,"bold"),text="*",command=lambda:click("*"),bg="powder blue").grid(row=3,column=3)
#________________________________________________________________________________________________________
button0=Button(calculator,padx=20,pady=10,bd=8, fg="black",font=("arial",20,"bold"),text="0",command=lambda:click(0), bg="powder blue").grid(row=4,column=0)
buttonclr=Button(calculator,padx=20,pady=10,bd=8, fg="black",font=("arial",20,"bold"),text="C", command=clear, bg="powder blue").grid(row=4,column=1)
buttoneql=Button(calculator,padx=20,pady=10,bd=8, fg="black",font=("arial",20,"bold"),text="=",command=equalto, bg="powder blue").grid(row=4,column=2)
buttondiv=Button(calculator,padx=20,pady=10,bd=8, fg="black",font=("arial",20,"bold"),text="/",command=lambda:click("/"),bg="powder blue").grid(row=4,column=3)

calculator.mainloop()

# %%
from tkinter import*
class calc:
    def __init__(self):
        self.calculator=Tk()
        self.calculator.title("CALCULATOR")
        self.empty=""
        self.inputval= StringVar()
        self.start=start()
    def start(self):
        self.screen=Entry(calculator,font=('arial',20,"bold"), bd=30, insertwidth=4,text=inputval,bg="powder blue", justify="right").grid(columnspan=4)
        self.button7=Button(calculator,padx=20,pady=10,bd=8, fg="black",font=("arial",20,"bold"),text="7",command=lambda:click(7),bg="powder blue").grid(row=1,column=0)
        self.button8=Button(calculator,padx=20,pady=10,bd=8, fg="black",font=("arial",20,"bold"),text="8",command=lambda:click(8),bg="powder blue").grid(row=1,column=1)
        self.button9=Button(calculator,padx=20,pady=10,bd=8, fg="black",font=("arial",20,"bold"),text="9",command=lambda:click(9),bg="powder blue").grid(row=1,column=2)
        self.add=Button(calculator,padx=20,pady=10,bd=8, fg="black",font=("arial",20,"bold"),text="+",command=lambda:click("+"),bg="powder blue").grid(row=1,column=3)
#________________________________________________________________________________________________________
        self.button4=Button(calculator,padx=20,pady=10,bd=8, fg="black",font=("arial",20,"bold"),text="4",command=lambda:click(4),bg="powder blue").grid(row=2,column=0)
        self.button5=Button(calculator,padx=20,pady=10,bd=8, fg="black",font=("arial",20,"bold"),text="5",command=lambda:click(5),bg="powder blue").grid(row=2,column=1)
        self.button6=Button(calculator,padx=20,pady=10,bd=8, fg="black",font=("arial",20,"bold"),text="6",command=lambda:click(6),bg="powder blue").grid(row=2,column=2)
        calculator.mainloop()
    def click(num):
        global empty
        empty=empty+ str(num)
        inputval.set(empty)
        calculator.mainloop()
    def clear():
        global empty
        empty=""
        inputval.set(empty)
        calculator.mainloop()
    def equalto():
        global empty
        sumup=str(eval(empty))
        inputval.set(sumup)
        empty=""
        calculator.mainloop()
ob=calc
